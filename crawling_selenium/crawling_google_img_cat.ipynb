# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

URL = 'https://www.google.com/imghp?hl=ko&ogbl'
driver.get(url=URL)

driver.implicitly_wait(time_to_wait=10)

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

elem = driver.find_element(By.CSS_SELECTOR, 'textarea.gLFyf')
elem.send_keys('고양이')
elem.send_keys(Keys.RETURN)

# %%
import time
elem = driver.find_element(By.CSS_SELECTOR, 'body')
for i in range(60):
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)

try:
    driver.find_element(By.CSS_SELECTOR, 'input.LZ4I').click()

    for i in range(60):
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.1)
except:
    pass

# %%
links = []
images = driver.find_elements(By.CSS_SELECTOR, 'a.FRuiCf.islib.nfEiy > div.fR600b.islir > img')

for image in images:
    if image.get_attribute('src') is not None:
        links.append(image.get_attribute('src'))

print(' 찾은 이미지 개수 : ', len(links))
# Out:
#  찾은 이미지 개수 :  824

# %%
import urllib.request

count = 0
for i, v in enumerate(links):
    url = v
    urllib.request.urlretrieve(url, f'./cat/cat_{i}.jpg')
    count += 1

print(f'{count}개 이미지 다운로드 완료!')
# Out:
# 824개 이미지 다운로드 완료!
