# %%
# 봇 처럼 여겨지지 않기 위해 주피터 노트북 ipynb 파일 생성
# 크롤링을 어떻게 사이트에서 사람이 하는 것처럼 보일까가 중요

# 브라우저 꺼짐 방지 옵션
# chrome_options = Options()
# chrome_options.add_experimental_option("detach", True)

# https://pypi.org/project/webdriver-manager/
# selenium 4 참조
# pip install selenium
from selenium import webdriver

# pip install webdriver-manager
# from selenium.webdriver.chrome.service import Service as ChromeService
# from webdriver_manager.chrome import ChromeDriverManager
# driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# pip install chromedriver-autoinstaller
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()
driver = webdriver.Chrome()

URL='https://www.google.co.kr/imghp'
driver.get(url=URL)

# driver.implicitly_wait(time_to_wait=10) # 10초안에 웹페이지를 load 하면 바로 넘어가거나, 10초를 기다림

# %%
# 키 입력을 위한 라이브러리
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

elem = driver.find_element(By.CSS_SELECTOR, "textarea.gLFyf") # "태그.클래스선택자#아이디선택자 > 태그"
elem.send_keys("고양이") # TODO 수정할 것
elem.send_keys(Keys.RETURN)

# %%
import time
elem = driver.find_element(By.CSS_SELECTOR, "body")
for i in range(60):
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)

try:
    driver.find_element(By.CSS_SELECTOR, "input.LZ4I").click() # 결과 더보기 버튼이 있는 경우 클릭!

    for i in range(60):
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.1)
except:
    pass

# %%
links = []
images = driver.find_elements(By.CSS_SELECTOR, "a.FRuiCf.islib.nfEiy > div.fR600b.islir > img") #find_elements 복수개
# print(images.get_attribute('src'))
for image in images:
    if image.get_attribute('src') is not None:
        links.append(image.get_attribute('src'))

print(' 찾은 이미지 개수: ', len(links))
# Out:
#  찾은 이미지 개수:  860

# %%
import urllib.request
# import os

# path = "./cat"
# try:
#     os.mkdir(path)
# except:
#     pass

from tqdm import tqdm

count = 0
for idx, value in enumerate(tqdm(links)):
    # urllib.request.urlretrieve: 이미지의 주소와 다운받을 경로를 적어주면 해당 위치에 이미지를 내려 받는다.
    url = value
    urllib.request.urlretrieve(url, f'./cat/cat_{idx}.jpg')
    count += 1

print(f'{count}개 이미지 다운로드 완료')
# Out:
# 63it [00:16,  3.78it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 16
#      13 for idx, value in tqdm(enumerate(links)):
#      14     # urllib.request.urlretrieve: 이미지의 주소와 다운받을 경로를 적어주면 해당 위치에 이미지를 내려 받는다.
#      15     url = value
# ---> 16     urllib.request.urlretrieve(url, f'./cat/cat_{idx}.jpg')
#      17     count += 1
#      19 print(f'{count}개 이미지 다운로드 완료')
#
# File c:\Users\J\.pyenv\pyenv-win\versions\3.11.0b4\Lib\urllib\request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
# ...
